# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data_analysis_challenge_data.csv')
df
# Out:
#       MONTH STORECODE  DAY BILL_ID  BILL_AMT  QTY  VALUE  PRICE  \
# 0        M1        N1    4    T375     225.0  1.0  225.0  225.0
# 1        M1        N1    4    T379      95.0  1.0   95.0   95.0
# 2        M1        N1    4    T381      10.0  1.0   10.0   10.0
# 3        M1        N1    4    T382     108.0  1.0  108.0  108.0
# 4        M1        N1    4    T384      19.0  1.0   19.0   19.0
# ...     ...       ...  ...     ...       ...  ...    ...    ...
# 26980    M3       N10   31   T5999      10.0  1.0   10.0   10.0
# 26981    M3       N10   31   T6007      88.0  1.0   10.0   10.0
# 26982    M3       N10   31   T6007      88.0  2.0   20.0   10.0
# 26983    M3       N10   31   T6007      88.0  1.0   58.0   58.0
# 26984    M3       N10   31   T6013      15.0  1.0   15.0   15.0
#
#                               GRP
# 0            BUTTER MARGR  (4/94)
# 1         CONFECTIONERY - ECLAIRS
# 2                       CHOCOLATE
# 3                    PACKAGED TEA
# ...

# %%
# Months
df.groupby(['DAY']).count()
# Out:
#      MONTH  STORECODE  BILL_ID  BILL_AMT   QTY  VALUE  PRICE   GRP
# DAY
# 1      542        542      542       542   542    542    542   542
# 2     1140       1140     1140      1140  1140   1140   1140  1140
# 3     1124       1124     1124      1124  1124   1124   1124  1124
# 4     1231       1231     1231      1231  1231   1231   1231  1231
# 5     1094       1094     1094      1094  1094   1094   1094  1094
# 6      781        781      781       781   781    781    781   781
# 7      955        955      955       955   955    955    955   955
# 8      989        989      989       989   989    989    989   989
# 9     1106       1106     1106      1106  1106   1106   1106  1106
# 10     765        765      765       765   765    765    765   765
# 11     973        973      973       973   973    973    973   973
# 12    1040       1040     1040      1040  1040   1040   1040  1040
# 13    1037       1037     1037      1037  1037   1037   1037  1037
# ...

# %%
# STORECODE
df.groupby(['STORECODE']).count()
# Out:
#            MONTH   DAY  BILL_ID  BILL_AMT   QTY  VALUE  PRICE   GRP
# STORECODE
# N1          4583  4583     4583      4583  4583   4583   4583  4583
# N10         2169  2169     2169      2169  2169   2169   2169  2169
# N2          1331  1331     1331      1331  1331   1331   1331  1331
# N3          1793  1793     1793      1793  1793   1793   1793  1793
# N4          3212  3212     3212      3212  3212   3212   3212  3212
# N5          4431  4431     4431      4431  4431   4431   4431  4431
# N6          1185  1185     1185      1185  1185   1185   1185  1185
# N7          5625  5625     5625      5625  5625   5625   5625  5625
# N8          1128  1128     1128      1128  1128   1128   1128  1128
# N9          1528  1528     1528      1528  1528   1528   1528  1528

# %%
# BILL_ID
df.groupby(['BILL_ID']).count()
# Out:
#          MONTH  STORECODE  DAY  BILL_AMT  QTY  VALUE  PRICE  GRP
# BILL_ID
# T1          10         10   10        10   10     10     10   10
# T10         13         13   13        13   13     13     13   13
# T100         8          8    8         8    8      8      8    8
# T1000        5          5    5         5    5      5      5    5
# T1001       15         15   15        15   15     15     15   15
# ...        ...        ...  ...       ...  ...    ...    ...  ...
# T995        11         11   11        11   11     11     11   11
# T996         2          2    2         2    2      2      2    2
# T997         1          1    1         1    1      1      1    1
# T998         8          8    8         8    8      8      8    8
# T999         4          4    4         4    4      4      4    4
#
# [6424 rows x 8 columns]

# %%
# Groups
df.groupby(['GRP']).count()
# Out:
#                             MONTH  STORECODE   DAY  BILL_ID  BILL_AMT   QTY  \
# GRP
# AFTER SHAVE LOTIONS             3          3     3        3         3     3
# AGARBATTI & DHOOPBATTI        118        118   118      118       118   118
# ALL AIR FRESHNERS(01/03)       86         86    86       86        86    86
# ALL IODISED SALT              450        450   450      450       450   450
# ANTACIDS                       63         63    63       63        63    63
# ...                           ...        ...   ...      ...       ...   ...
# TOOTH POWDERS                  19         19    19       19        19    19
# TWIN BLADES                    35         35    35       35        35    35
# VANASPATI CONS PACK (8/94)     64         64    64       64        64    64
# VERMICELLI & NOODLE          1330       1330  1330     1330      1330  1330
# WASHING POWDERS/LIQUIDS      1208       1208  1208     1208      1208  1208
#
#                             VALUE  PRICE
# GRP
# ...

# %% [markdown]
# Question 1

# %%
#df['BILL_AMT'].sum() # 7522182.25
grouped_df = df.groupby(['STORECODE','MONTH'])['BILL_AMT'].sum().reset_index()
# grouped_df
pivoted_df2 = grouped_df.pivot('MONTH','STORECODE','BILL_AMT')
plt.figure(figsize=(13,6))
sns.heatmap(pivoted_df2, annot=True, fmt='.1f', linewidth=0.1)

# %% [markdown]
# Question 2

# %%
grouped_df2 = df.groupby(['STORECODE', 'GRP'])['QTY'].sum().reset_index().sort_values(by=['STORECODE', 'QTY'], ascending=False)
#rouped_df3 = grouped_df2.sort_values(by=['STORECODE', 'QTY'], ascending=False)
grouped_df2
#= grouped_df2.groupby('GRP')['QTY'].rank()
n10df = grouped_df2[grouped_df2['STORECODE']=='N10']
n9df = grouped_df2[grouped_df2['STORECODE']=='N9']
n8df = grouped_df2[grouped_df2['STORECODE']=='N8']
n7df = grouped_df2[grouped_df2['STORECODE']=='N7']
n6df = grouped_df2[grouped_df2['STORECODE']=='N6']
n5df = grouped_df2[grouped_df2['STORECODE']=='N5']
n4df = grouped_df2[grouped_df2['STORECODE']=='N4']
n3df = grouped_df2[grouped_df2['STORECODE']=='N3']
n2df = grouped_df2[grouped_df2['STORECODE']=='N2']
n1df = grouped_df2[grouped_df2['STORECODE']=='N1']


n1df = n1df[n1df['QTY']==n1df['QTY'].max()]
n2df = n2df[n2df['QTY']==n2df['QTY'].max()]
n3df = n3df[n3df['QTY']==n3df['QTY'].max()]
n4df = n4df[n4df['QTY']==n4df['QTY'].max()]
n5df = n5df[n5df['QTY']==n5df['QTY'].max()]
n6df = n6df[n6df['QTY']==n6df['QTY'].max()]
n7df = n7df[n7df['QTY']==n7df['QTY'].max()]
n8df = n8df[n8df['QTY']==n8df['QTY'].max()]
n9df = n9df[n9df['QTY']==n9df['QTY'].max()]
n10df = n10df[n10df['QTY']==n10df['QTY'].max()]

frames = [n1df,
n2df,
n3df,
n4df,
n5df,
n6df,
n7df,
n8df,
n9df,
n10df]

result = pd.concat(frames)
result
# Out:
#     STORECODE                            GRP      QTY
# 49         N1  REFINED EDIBLE OILS-ALL PACKS  32108.0
# 129        N2              CLEANERS - TOILET   8027.0
# 183        N3     BISCUITS - CORE & NON CORE    803.0
# 245        N4     BISCUITS - CORE & NON CORE   2081.0
# 305        N5     BISCUITS - CORE & NON CORE   2691.0
# 373        N6     BISCUITS - CORE & NON CORE    545.0
# 454        N7           HAIR OILS PKTP(8/02)   6037.0
# 501        N8     BISCUITS - CORE & NON CORE   1009.0
# 562        N9     BISCUITS - CORE & NON CORE    395.0
# 73        N10     BISCUITS - CORE & NON CORE   1333.0

# %% [markdown]
# Question 3

# %%
grouped_df3 = df.groupby(['STORECODE', 'MONTH', 'DAY'])['BILL_AMT'].sum().reset_index().sort_values(by=['STORECODE', 'MONTH','BILL_AMT'], ascending=False)
grouped_df3

n10df = grouped_df3[grouped_df3['STORECODE']=='N10']
n9df = grouped_df3[grouped_df3['STORECODE']=='N9']
n8df = grouped_df3[grouped_df3['STORECODE']=='N8']
n7df = grouped_df3[grouped_df3['STORECODE']=='N7']
n6df = grouped_df3[grouped_df3['STORECODE']=='N6']
n5df = grouped_df3[grouped_df3['STORECODE']=='N5']
n4df = grouped_df3[grouped_df3['STORECODE']=='N4']
n3df = grouped_df3[grouped_df3['STORECODE']=='N3']
n2df = grouped_df3[grouped_df3['STORECODE']=='N2']
n1df = grouped_df3[grouped_df3['STORECODE']=='N1']

n1df = n1df[n1df['BILL_AMT']==n1df['BILL_AMT'].max()]
n2df = n2df[n2df['BILL_AMT']==n2df['BILL_AMT'].max()]
n3df = n3df[n3df['BILL_AMT']==n3df['BILL_AMT'].max()]
n4df = n4df[n4df['BILL_AMT']==n4df['BILL_AMT'].max()]
n5df = n5df[n5df['BILL_AMT']==n5df['BILL_AMT'].max()]
n6df = n6df[n6df['BILL_AMT']==n6df['BILL_AMT'].max()]
n7df = n7df[n7df['BILL_AMT']==n7df['BILL_AMT'].max()]
n8df = n8df[n8df['BILL_AMT']==n8df['BILL_AMT'].max()]
n9df = n9df[n9df['BILL_AMT']==n9df['BILL_AMT'].max()]
n10df = n10df[n10df['BILL_AMT']==n10df['BILL_AMT'].max()]

frames = [n1df,
n2df,
n3df,
n4df,
n5df,
n6df,
n7df,
n8df,
n9df,
n10df]

result = pd.concat(frames)
result['day_month'] = result['MONTH'].astype(str) + "-" + result['DAY'].astype(str)
result = result.drop(columns=['MONTH', 'DAY'])
result
# Out:
#     STORECODE   BILL_AMT day_month
# 19         N1   46686.35     M1-29
# 181        N2   86952.00     M2-27
# 205        N3   36815.00      M1-3
# 313        N4   46190.00      M3-3
# 361        N5   47714.00      M2-2
# 461        N6   29529.00     M3-21
# 491        N7   83141.45      M2-4
# 584        N8   70478.00      M3-4
# 635        N9  186242.25      M2-8
# 116       N10   57538.00     M2-29

# %% [markdown]
# Question 4

# %%
grouped_df4 = df.groupby(['STORECODE', 'MONTH'])['BILL_AMT'].sum().reset_index().sort_values(by=['STORECODE', 'BILL_AMT'], ascending=False)

n10df = grouped_df4[grouped_df4['STORECODE']=='N10']
n9df = grouped_df4[grouped_df4['STORECODE']=='N9']
n8df = grouped_df4[grouped_df4['STORECODE']=='N8']
n7df = grouped_df4[grouped_df4['STORECODE']=='N7']
n6df = grouped_df4[grouped_df4['STORECODE']=='N6']
n5df = grouped_df4[grouped_df4['STORECODE']=='N5']
n4df = grouped_df4[grouped_df4['STORECODE']=='N4']
n3df = grouped_df4[grouped_df4['STORECODE']=='N3']
n2df = grouped_df4[grouped_df4['STORECODE']=='N2']
n1df = grouped_df4[grouped_df4['STORECODE']=='N1']


n1df = n1df[n1df['BILL_AMT']==n1df['BILL_AMT'].max()]
n2df = n2df[n2df['BILL_AMT']==n2df['BILL_AMT'].max()]
n3df = n3df[n3df['BILL_AMT']==n3df['BILL_AMT'].max()]
n4df = n4df[n4df['BILL_AMT']==n4df['BILL_AMT'].max()]
n5df = n5df[n5df['BILL_AMT']==n5df['BILL_AMT'].max()]
n6df = n6df[n6df['BILL_AMT']==n6df['BILL_AMT'].max()]
n7df = n7df[n7df['BILL_AMT']==n7df['BILL_AMT'].max()]
n8df = n8df[n8df['BILL_AMT']==n8df['BILL_AMT'].max()]
n9df = n9df[n9df['BILL_AMT']==n9df['BILL_AMT'].max()]
n10df = n10df[n10df['BILL_AMT']==n10df['BILL_AMT'].max()]

frames = [n1df,
n2df,
n3df,
n4df,
n5df,
n6df,
n7df,
n8df,
n9df,
n10df]

result = pd.concat(frames)
result
# Out:
#    STORECODE MONTH   BILL_AMT
# 0         N1    M1  312485.59
# 8         N2    M3  282863.00
# 9         N3    M1  222674.50
# 14        N4    M3  341940.89
# 17        N5    M3  307764.00
# 20        N6    M3  276056.00
# 22        N7    M2  477371.73
# 26        N8    M3  235728.22
# 28        N9    M2  878590.29
# 4        N10    M2  280629.00
